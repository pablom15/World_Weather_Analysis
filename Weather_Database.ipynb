# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 599

# %%
#Open Weather Map API url link
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
#Example city with snow
city_url = url + "&q=" + "Chapelco"
print(city_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5ac43d4309d205fbe4be6b192965bfb7&q=Chapelco

# %%
# Testing rain and snow code
city_url = url + "&q=" + "Chapelco"
city_weather = requests.get(city_url).json()

try:
    city_rain  = city_weather['rain']['1h']
except KeyError:
    city_rain = 0
try:
    city_snow = city_weather['snow']['1h']
except:
    city_snow = 0

print(f"Rain: {city_rain} and Snow: {city_snow}")
# Out:
# Rain: 0 and Snow: 5.12

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_des = city_weather['weather'][0]['description']
        try:
            city_rain  = city_weather['rain']['1h']
        except KeyError:
            city_rain = 0
        try:
            city_snow = city_weather['snow']['1h']
        except KeyError:
            city_snow = 0
    
        # Convert the date to ISO standard.
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_des, 
                          "Rain (inches)": city_rain,
                          "Snow (inches)": city_snow})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | ushuaia
# Processing Record 2 of Set 1 | georgetown
# Processing Record 3 of Set 1 | palmas bellas
# Processing Record 4 of Set 1 | ahipara
# Processing Record 5 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 6 of Set 1 | constitucion
# Processing Record 7 of Set 1 | mount gambier
# Processing Record 8 of Set 1 | ojinaga
# Processing Record 9 of Set 1 | iqaluit
# Processing Record 10 of Set 1 | port elizabeth
# Processing Record 11 of Set 1 | kruisfontein
# Processing Record 12 of Set 1 | punta arenas
# Processing Record 13 of Set 1 | bredasdorp
# Processing Record 14 of Set 1 | impfondo
# Processing Record 15 of Set 1 | thompson
# Processing Record 16 of Set 1 | rikitea
# Processing Record 17 of Set 1 | gillette
# Processing Record 18 of Set 1 | pevek
# Processing Record 19 of Set 1 | cape town
# Processing Record 20 of Set 1 | talnakh
# Processing Record 21 of Set 1 | westport
# Processing Record 22 of Set 1 | pangkalanbuun
# Processing Record 23 of Set 1 | kapaa
# Processing Record 24 of Set 1 | mosquera
# Processing Record 25 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 26 of Set 1 | vaini
# Processing Record 27 of Set 1 | owosso
# Processing Record 28 of Set 1 | guadalupe y calvo
# Processing Record 29 of Set 1 | senanga
# Processing Record 30 of Set 1 | vagur
# Processing Record 31 of Set 1 | mataura
# Processing Record 32 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 33 of Set 1 | palmer
# Processing Record 34 of Set 1 | cefalu
# Processing Record 35 of Set 1 | scottsburgh
# City not found. Skipping...
# Processing Record 36 of Set 1 | nikolskoye
# Processing Record 37 of Set 1 | upernavik
# Processing Record 38 of Set 1 | palana
# Processing Record 39 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 40 of Set 1 | hohhot
# Processing Record 41 of Set 1 | tianpeng
# Processing Record 42 of Set 1 | hemsedal
# Processing Record 43 of Set 1 | lagoa
# Processing Record 44 of Set 1 | hasaki
# Processing Record 45 of Set 1 | noumea
# Processing Record 46 of Set 1 | tebingtinggi
# Processing Record 47 of Set 1 | airai
# Processing Record 48 of Set 1 | lasa
# Processing Record 49 of Set 1 | makakilo city
# Processing Record 50 of Set 1 | tasiilaq
# Processing Record 1 of Set 2 | albany
# Processing Record 2 of Set 2 | gushikawa
# Processing Record 3 of Set 2 | orange cove
# Processing Record 4 of Set 2 | verkhnevilyuysk
# Processing Record 5 of Set 2 | safaga
# Processing Record 6 of Set 2 | hermanus
# Processing Record 7 of Set 2 | tabou
# Processing Record 8 of Set 2 | carnarvon
# Processing Record 9 of Set 2 | castro
# Processing Record 10 of Set 2 | fuerte olimpo
# Processing Record 11 of Set 2 | qaanaaq
# Processing Record 12 of Set 2 | samarai
# Processing Record 13 of Set 2 | hilo
# Processing Record 14 of Set 2 | adrar
# Processing Record 15 of Set 2 | new norfolk
# Processing Record 16 of Set 2 | padang
# Processing Record 17 of Set 2 | busselton
# Processing Record 18 of Set 2 | bengkulu
# Processing Record 19 of Set 2 | rapar
# Processing Record 20 of Set 2 | victoria
# Processing Record 21 of Set 2 | chuy
# Processing Record 22 of Set 2 | kavieng
# Processing Record 23 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 24 of Set 2 | mitchell
# Processing Record 25 of Set 2 | tiksi
# Processing Record 26 of Set 2 | souillac
# Processing Record 27 of Set 2 | hobart
# Processing Record 28 of Set 2 | atuona
# Processing Record 29 of Set 2 | kerema
# Processing Record 30 of Set 2 | nabire
# Processing Record 31 of Set 2 | yerofey pavlovich
# Processing Record 32 of Set 2 | ilulissat
# Processing Record 33 of Set 2 | norman wells
# Processing Record 34 of Set 2 | bethel
# Processing Record 35 of Set 2 | orapa
# Processing Record 36 of Set 2 | nyurba
# Processing Record 37 of Set 2 | arraial do cabo
# Processing Record 38 of Set 2 | ballina
# Processing Record 39 of Set 2 | tuktoyaktuk
# Processing Record 40 of Set 2 | salalah
# Processing Record 41 of Set 2 | port lincoln
# Processing Record 42 of Set 2 | bluff
# Processing Record 43 of Set 2 | khatanga
# Processing Record 44 of Set 2 | kaitangata
# Processing Record 45 of Set 2 | broome
# Processing Record 46 of Set 2 | atar
# Processing Record 47 of Set 2 | quatre cocos
# Processing Record 48 of Set 2 | cidreira
# Processing Record 49 of Set 2 | juneau
# Processing Record 50 of Set 2 | coruripe
# Processing Record 1 of Set 3 | saskylakh
# Processing Record 2 of Set 3 | sorland
# Processing Record 3 of Set 3 | east london
# Processing Record 4 of Set 3 | mar del plata
# Processing Record 5 of Set 3 | caravelas
# Processing Record 6 of Set 3 | khormuj
# City not found. Skipping...
# Processing Record 7 of Set 3 | vanavara
# Processing Record 8 of Set 3 | narsaq
# Processing Record 9 of Set 3 | gamba
# Processing Record 10 of Set 3 | san cristobal
# Processing Record 11 of Set 3 | mahebourg
# Processing Record 12 of Set 3 | sladkovo
# Processing Record 13 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 14 of Set 3 | yellowknife
# Processing Record 15 of Set 3 | biak
# Processing Record 16 of Set 3 | canutama
# Processing Record 17 of Set 3 | gerash
# Processing Record 18 of Set 3 | inirida
# Processing Record 19 of Set 3 | longyearbyen
# Processing Record 20 of Set 3 | farmington
# Processing Record 21 of Set 3 | saint-philippe
# Processing Record 22 of Set 3 | nome
# Processing Record 23 of Set 3 | dinan
# Processing Record 24 of Set 3 | atasu
# Processing Record 25 of Set 3 | bambous virieux
# Processing Record 26 of Set 3 | puerto ayora
# Processing Record 27 of Set 3 | senno
# Processing Record 28 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 29 of Set 3 | cherskiy
# Processing Record 30 of Set 3 | bolungarvik
# City not found. Skipping...
# Processing Record 31 of Set 3 | rio de janeiro
# Processing Record 32 of Set 3 | uglovskoye
# Processing Record 33 of Set 3 | leningradskiy
# Processing Record 34 of Set 3 | hithadhoo
# Processing Record 35 of Set 3 | san quintin
# Processing Record 36 of Set 3 | rawson
# Processing Record 37 of Set 3 | ponta do sol
# Processing Record 38 of Set 3 | montepuez
# Processing Record 39 of Set 3 | porto santo
# Processing Record 40 of Set 3 | guerrero negro
# Processing Record 41 of Set 3 | kuche
# City not found. Skipping...
# Processing Record 42 of Set 3 | maloshuyka
# City not found. Skipping...
# Processing Record 43 of Set 3 | punta alta
# Processing Record 44 of Set 3 | isangel
# Processing Record 45 of Set 3 | kontagora
# Processing Record 46 of Set 3 | rio gallegos
# Processing Record 47 of Set 3 | marion
# Processing Record 48 of Set 3 | avarua
# Processing Record 49 of Set 3 | mezen
# Processing Record 50 of Set 3 | port alfred
# Processing Record 1 of Set 4 | kavaratti
# Processing Record 2 of Set 4 | barra patuca
# Processing Record 3 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 4 of Set 4 | vila franca do campo
# Processing Record 5 of Set 4 | yelizavetino
# Processing Record 6 of Set 4 | jamestown
# Processing Record 7 of Set 4 | lebu
# Processing Record 8 of Set 4 | saint-pierre
# Processing Record 9 of Set 4 | faanui
# Processing Record 10 of Set 4 | hambantota
# Processing Record 11 of Set 4 | maceio
# Processing Record 12 of Set 4 | rungata
# City not found. Skipping...
# Processing Record 13 of Set 4 | otradnoye
# Processing Record 14 of Set 4 | dikson
# Processing Record 15 of Set 4 | yeppoon
# Processing Record 16 of Set 4 | saldanha
# Processing Record 17 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 18 of Set 4 | manado
# Processing Record 19 of Set 4 | batagay
# Processing Record 20 of Set 4 | raudeberg
# Processing Record 21 of Set 4 | oktyabrskoye
# Processing Record 22 of Set 4 | barra do bugres
# Processing Record 23 of Set 4 | praia da vitoria
# Processing Record 24 of Set 4 | labutta
# City not found. Skipping...
# Processing Record 25 of Set 4 | ampanihy
# Processing Record 26 of Set 4 | cabo san lucas
# Processing Record 27 of Set 4 | port blair
# Processing Record 28 of Set 4 | martapura
# Processing Record 29 of Set 4 | russell
# Processing Record 30 of Set 4 | marawi
# Processing Record 31 of Set 4 | port moresby
# Processing Record 32 of Set 4 | colares
# Processing Record 33 of Set 4 | kargasok
# Processing Record 34 of Set 4 | namatanai
# Processing Record 35 of Set 4 | ribeira grande
# Processing Record 36 of Set 4 | tomatlan
# Processing Record 37 of Set 4 | nuuk
# Processing Record 38 of Set 4 | banyuwangi
# Processing Record 39 of Set 4 | berezovyy
# Processing Record 40 of Set 4 | smithers
# Processing Record 41 of Set 4 | chokurdakh
# Processing Record 42 of Set 4 | faya
# Processing Record 43 of Set 4 | altamira
# Processing Record 44 of Set 4 | rodionovo-nesvetayskaya
# Processing Record 45 of Set 4 | talcahuano
# Processing Record 46 of Set 4 | raton
# Processing Record 47 of Set 4 | sawakin
# Processing Record 48 of Set 4 | aitape
# Processing Record 49 of Set 4 | mahroni
# Processing Record 50 of Set 4 | payyannur
# Processing Record 1 of Set 5 | bubaque
# Processing Record 2 of Set 5 | zhigansk
# Processing Record 3 of Set 5 | launceston
# Processing Record 4 of Set 5 | gornopravdinsk
# Processing Record 5 of Set 5 | bull savanna
# Processing Record 6 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 7 of Set 5 | fairbanks
# Processing Record 8 of Set 5 | boddam
# Processing Record 9 of Set 5 | severo-kurilsk
# Processing Record 10 of Set 5 | wooster
# Processing Record 11 of Set 5 | barroualie
# City not found. Skipping...
# Processing Record 12 of Set 5 | saint anthony
# Processing Record 13 of Set 5 | taolanaro
# City not found. Skipping...
# Processing Record 14 of Set 5 | camana
# Processing Record 15 of Set 5 | gravelbourg
# Processing Record 16 of Set 5 | lorengau
# Processing Record 17 of Set 5 | yumen
# Processing Record 18 of Set 5 | ovalle
# Processing Record 19 of Set 5 | la union
# Processing Record 20 of Set 5 | kawana waters
# City not found. Skipping...
# Processing Record 21 of Set 5 | kashi
# Processing Record 22 of Set 5 | sur
# Processing Record 23 of Set 5 | berlevag
# Processing Record 24 of Set 5 | hervey bay
# Processing Record 25 of Set 5 | gongzhuling
# Processing Record 26 of Set 5 | sakaiminato
# Processing Record 27 of Set 5 | necochea
# Processing Record 28 of Set 5 | phalodi
# Processing Record 29 of Set 5 | itoman
# Processing Record 30 of Set 5 | krasnovishersk
# Processing Record 31 of Set 5 | malindi
# Processing Record 32 of Set 5 | plettenberg bay
# Processing Record 33 of Set 5 | altay
# Processing Record 34 of Set 5 | las vegas
# Processing Record 35 of Set 5 | sisimiut
# Processing Record 36 of Set 5 | columbus
# Processing Record 37 of Set 5 | leshukonskoye
# Processing Record 38 of Set 5 | butaritari
# Processing Record 39 of Set 5 | falam
# Processing Record 40 of Set 5 | barrow
# Processing Record 41 of Set 5 | grand gaube
# Processing Record 42 of Set 5 | klyuchi
# Processing Record 43 of Set 5 | nueva loja
# Processing Record 44 of Set 5 | port augusta
# Processing Record 45 of Set 5 | amapa
# Processing Record 46 of Set 5 | tidore
# City not found. Skipping...
# Processing Record 47 of Set 5 | shache
# Processing Record 48 of Set 5 | gurupa
# Processing Record 49 of Set 5 | half moon bay
# Processing Record 50 of Set 5 | kahului
# Processing Record 1 of Set 6 | iskateley
# Processing Record 2 of Set 6 | lumeje
# Processing Record 3 of Set 6 | touros
# Processing Record 4 of Set 6 | kodinsk
# Processing Record 5 of Set 6 | sofiysk
# City not found. Skipping...
# Processing Record 6 of Set 6 | kuytun
# Processing Record 7 of Set 6 | viedma
# Processing Record 8 of Set 6 | esperance
# Processing Record 9 of Set 6 | hamilton
# Processing Record 10 of Set 6 | firovo
# Processing Record 11 of Set 6 | maraba
# Processing Record 12 of Set 6 | marshall
# Processing Record 13 of Set 6 | nanortalik
# Processing Record 14 of Set 6 | ukiah
# Processing Record 15 of Set 6 | margate
# Processing Record 16 of Set 6 | lavrentiya
# Processing Record 17 of Set 6 | clyde river
# Processing Record 18 of Set 6 | saint-orens-de-gameville
# Processing Record 19 of Set 6 | moranbah
# Processing Record 20 of Set 6 | surin
# Processing Record 21 of Set 6 | slonim
# Processing Record 22 of Set 6 | meulaboh
# Processing Record 23 of Set 6 | tezu
# Processing Record 24 of Set 6 | am timan
# Processing Record 25 of Set 6 | sinnamary
# Processing Record 26 of Set 6 | te anau
# Processing Record 27 of Set 6 | san patricio
# Processing Record 28 of Set 6 | abu samrah
# Processing Record 29 of Set 6 | sherlovaya gora
# Processing Record 30 of Set 6 | ulladulla
# Processing Record 31 of Set 6 | cedar city
# Processing Record 32 of Set 6 | puerto colombia
# Processing Record 33 of Set 6 | emporia
# Processing Record 34 of Set 6 | lakatoro
# Processing Record 35 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 36 of Set 6 | alekseyevsk
# Processing Record 37 of Set 6 | liseleje
# Processing Record 38 of Set 6 | lar gerd
# City not found. Skipping...
# Processing Record 39 of Set 6 | bhadrak
# Processing Record 40 of Set 6 | longlac
# City not found. Skipping...
# Processing Record 41 of Set 6 | chicama
# Processing Record 42 of Set 6 | portland
# Processing Record 43 of Set 6 | visnes
# Processing Record 44 of Set 6 | allapalli
# Processing Record 45 of Set 6 | itaquitinga
# Processing Record 46 of Set 6 | jiroft
# City not found. Skipping...
# Processing Record 47 of Set 6 | alpena
# Processing Record 48 of Set 6 | hede
# Processing Record 49 of Set 6 | lerwick
# Processing Record 50 of Set 6 | harper
# Processing Record 1 of Set 7 | yemelyanovo
# Processing Record 2 of Set 7 | joshimath
# Processing Record 3 of Set 7 | tuatapere
# Processing Record 4 of Set 7 | ambodifototra
# City not found. Skipping...
# Processing Record 5 of Set 7 | melfort
# Processing Record 6 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 7 of Set 7 | mehamn
# Processing Record 8 of Set 7 | hofn
# Processing Record 9 of Set 7 | thinadhoo
# Processing Record 10 of Set 7 | garowe
# Processing Record 11 of Set 7 | kinshasa
# Processing Record 12 of Set 7 | pskov
# Processing Record 13 of Set 7 | mumford
# Processing Record 14 of Set 7 | andevoranto
# City not found. Skipping...
# Processing Record 15 of Set 7 | maniitsoq
# Processing Record 16 of Set 7 | inuvik
# Processing Record 17 of Set 7 | hwange
# Processing Record 18 of Set 7 | husavik
# Processing Record 19 of Set 7 | sao joao da barra
# Processing Record 20 of Set 7 | menongue
# Processing Record 21 of Set 7 | puerto escondido
# Processing Record 22 of Set 7 | baykalsk
# Processing Record 23 of Set 7 | ambulu
# Processing Record 24 of Set 7 | weymouth
# Processing Record 25 of Set 7 | vila velha
# Processing Record 26 of Set 7 | dubbo
# Processing Record 27 of Set 7 | ardakan
# Processing Record 28 of Set 7 | kieta
# Processing Record 29 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 30 of Set 7 | karratha
# Processing Record 31 of Set 7 | mahibadhoo
# Processing Record 32 of Set 7 | semnan
# Processing Record 33 of Set 7 | verkhnyaya toyma
# Processing Record 34 of Set 7 | javanrud
# Processing Record 35 of Set 7 | san vicente
# Processing Record 36 of Set 7 | vierzon
# Processing Record 37 of Set 7 | bahia honda
# Processing Record 38 of Set 7 | yamada
# Processing Record 39 of Set 7 | olafsvik
# Processing Record 40 of Set 7 | tiznit
# Processing Record 41 of Set 7 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 42 of Set 7 | solnechnyy
# Processing Record 43 of Set 7 | grindavik
# Processing Record 44 of Set 7 | deputatskiy
# Processing Record 45 of Set 7 | maxixe
# Processing Record 46 of Set 7 | eina
# Processing Record 47 of Set 7 | pinawa
# Processing Record 48 of Set 7 | belmonte
# Processing Record 49 of Set 7 | suez
# Processing Record 50 of Set 7 | bathsheba
# Processing Record 1 of Set 8 | richards bay
# Processing Record 2 of Set 8 | portoferraio
# Processing Record 3 of Set 8 | byron bay
# Processing Record 4 of Set 8 | fortuna
# Processing Record 5 of Set 8 | lasalgaon
# Processing Record 6 of Set 8 | veraval
# Processing Record 7 of Set 8 | klaksvik
# Processing Record 8 of Set 8 | irkutsk
# Processing Record 9 of Set 8 | taga
# Processing Record 10 of Set 8 | alofi
# Processing Record 11 of Set 8 | susangerd
# Processing Record 12 of Set 8 | huetamo
# City not found. Skipping...
# Processing Record 13 of Set 8 | kodiak
# Processing Record 14 of Set 8 | ubinskoye
# Processing Record 15 of Set 8 | verkh-usugli
# Processing Record 16 of Set 8 | yeltsovka
# City not found. Skipping...
# Processing Record 17 of Set 8 | shakawe
# Processing Record 18 of Set 8 | sapao
# City not found. Skipping...
# Processing Record 19 of Set 8 | pucallpa
# Processing Record 20 of Set 8 | banjarmasin
# Processing Record 21 of Set 8 | merauke
# Processing Record 22 of Set 8 | soyo
# Processing Record 23 of Set 8 | kulhudhuffushi
# Processing Record 24 of Set 8 | dakar
# Processing Record 25 of Set 8 | cayenne
# Processing Record 26 of Set 8 | rockland
# Processing Record 27 of Set 8 | taksimo
# Processing Record 28 of Set 8 | jibuti
# Processing Record 29 of Set 8 | beringovskiy
# Processing Record 30 of Set 8 | ambilobe
# Processing Record 31 of Set 8 | abalak
# Processing Record 32 of Set 8 | gavle
# Processing Record 33 of Set 8 | labuhan
# Processing Record 34 of Set 8 | yanan
# City not found. Skipping...
# Processing Record 35 of Set 8 | khadro
# Processing Record 36 of Set 8 | monrovia
# Processing Record 37 of Set 8 | acapulco
# Processing Record 38 of Set 8 | gizo
# Processing Record 39 of Set 8 | mabay
# Processing Record 40 of Set 8 | bargal
# City not found. Skipping...
# Processing Record 41 of Set 8 | carutapera
# Processing Record 42 of Set 8 | plouzane
# Processing Record 43 of Set 8 | gedo
# Processing Record 44 of Set 8 | luderitz
# Processing Record 45 of Set 8 | owando
# Processing Record 46 of Set 8 | severnyy
# Processing Record 47 of Set 8 | naryan-mar
# Processing Record 48 of Set 8 | tuy hoa
# Processing Record 49 of Set 8 | mys shmidta
# City not found. Skipping...
# Processing Record 50 of Set 8 | reconquista
# Processing Record 1 of Set 9 | coquimbo
# Processing Record 2 of Set 9 | karaul
# City not found. Skipping...
# Processing Record 3 of Set 9 | tabiauea
# City not found. Skipping...
# Processing Record 4 of Set 9 | hojai
# Processing Record 5 of Set 9 | rakiv lis
# Processing Record 6 of Set 9 | emerald
# Processing Record 7 of Set 9 | sao filipe
# Processing Record 8 of Set 9 | banmo
# City not found. Skipping...
# Processing Record 9 of Set 9 | nouadhibou
# Processing Record 10 of Set 9 | san lorenzo
# Processing Record 11 of Set 9 | turukhansk
# Processing Record 12 of Set 9 | isla mujeres
# Processing Record 13 of Set 9 | calama
# Processing Record 14 of Set 9 | muana
# Processing Record 15 of Set 9 | aykhal
# Processing Record 16 of Set 9 | kuryk
# Processing Record 17 of Set 9 | tubruq
# City not found. Skipping...
# Processing Record 18 of Set 9 | chilca
# Processing Record 19 of Set 9 | marsa matruh
# Processing Record 20 of Set 9 | eustis
# Processing Record 21 of Set 9 | kashan
# Processing Record 22 of Set 9 | matara
# Processing Record 23 of Set 9 | los llanos de aridane
# Processing Record 24 of Set 9 | bilma
# Processing Record 25 of Set 9 | vardo
# Processing Record 26 of Set 9 | pisco
# Processing Record 27 of Set 9 | namibe
# Processing Record 28 of Set 9 | lata
# Processing Record 29 of Set 9 | sao felix do xingu
# Processing Record 30 of Set 9 | timbo
# Processing Record 31 of Set 9 | hovd
# Processing Record 32 of Set 9 | felidhoo
# City not found. Skipping...
# Processing Record 33 of Set 9 | satitoa
# City not found. Skipping...
# Processing Record 34 of Set 9 | ust-ishim
# Processing Record 35 of Set 9 | linxia
# Processing Record 36 of Set 9 | jinka
# Processing Record 37 of Set 9 | codrington
# Processing Record 38 of Set 9 | passo de camaragibe
# Processing Record 39 of Set 9 | camacupa
# Processing Record 40 of Set 9 | saint joseph
# Processing Record 41 of Set 9 | cascais
# Processing Record 42 of Set 9 | khani
# Processing Record 43 of Set 9 | khobi
# Processing Record 44 of Set 9 | yaan
# Processing Record 45 of Set 9 | pointe michel
# Processing Record 46 of Set 9 | chermoz
# Processing Record 47 of Set 9 | taltal
# Processing Record 48 of Set 9 | buala
# Processing Record 49 of Set 9 | raymondville
# Processing Record 50 of Set 9 | taoudenni
# Processing Record 1 of Set 10 | malibu
# Processing Record 2 of Set 10 | sitka
# Processing Record 3 of Set 10 | marabba
# Processing Record 4 of Set 10 | odweyne
# Processing Record 5 of Set 10 | mahina
# Processing Record 6 of Set 10 | dunedin
# Processing Record 7 of Set 10 | saint george
# Processing Record 8 of Set 10 | okha
# Processing Record 9 of Set 10 | vrangel
# Processing Record 10 of Set 10 | kumluca
# Processing Record 11 of Set 10 | bontang
# Processing Record 12 of Set 10 | whitehorse
# Processing Record 13 of Set 10 | sortland
# Processing Record 14 of Set 10 | la ronge
# Processing Record 15 of Set 10 | gayny
# Processing Record 16 of Set 10 | coahuayana
# Processing Record 17 of Set 10 | lapeer
# Processing Record 18 of Set 10 | fort morgan
# Processing Record 19 of Set 10 | vestmannaeyjar
# Processing Record 20 of Set 10 | constantine
# Processing Record 21 of Set 10 | jieshi
# Processing Record 22 of Set 10 | vao
# Processing Record 23 of Set 10 | arlit
# Processing Record 24 of Set 10 | geraldton
# Processing Record 25 of Set 10 | uruzgan
# Processing Record 26 of Set 10 | mouzakion
# City not found. Skipping...
# Processing Record 27 of Set 10 | avera
# Processing Record 28 of Set 10 | vostok
# Processing Record 29 of Set 10 | katsuura
# Processing Record 30 of Set 10 | cap malheureux
# Processing Record 31 of Set 10 | aklavik
# Processing Record 32 of Set 10 | hit
# Processing Record 33 of Set 10 | port hardy
# Processing Record 34 of Set 10 | aswan
# Processing Record 35 of Set 10 | abnub
# Processing Record 36 of Set 10 | jinxiang
# Processing Record 37 of Set 10 | srednekolymsk
# Processing Record 38 of Set 10 | bonthe
# Processing Record 39 of Set 10 | kalmunai
# Processing Record 40 of Set 10 | seddon
# Processing Record 41 of Set 10 | nusaybin
# Processing Record 42 of Set 10 | sibolga
# Processing Record 43 of Set 10 | buraydah
# Processing Record 44 of Set 10 | pamanukan
# Processing Record 45 of Set 10 | gravdal
# Processing Record 46 of Set 10 | kaeo
# Processing Record 47 of Set 10 | zhanaozen
# Processing Record 48 of Set 10 | halifax
# Processing Record 49 of Set 10 | amahai
# Processing Record 50 of Set 10 | las palmas
# Processing Record 1 of Set 11 | manitouwadge
# Processing Record 2 of Set 11 | nhulunbuy
# Processing Record 3 of Set 11 | evensk
# Processing Record 4 of Set 11 | ginda
# Processing Record 5 of Set 11 | gimangpang
# City not found. Skipping...
# Processing Record 6 of Set 11 | yerbogachen
# Processing Record 7 of Set 11 | campos
# Processing Record 8 of Set 11 | nemuro
# Processing Record 9 of Set 11 | kyzyl-suu
# Processing Record 10 of Set 11 | alvarado
# Processing Record 11 of Set 11 | kloulklubed
# Processing Record 12 of Set 11 | correia pinto
# Processing Record 13 of Set 11 | ningan
# City not found. Skipping...
# Processing Record 14 of Set 11 | vaitupu
# City not found. Skipping...
# Processing Record 15 of Set 11 | ancud
# Processing Record 16 of Set 11 | obo
# Processing Record 17 of Set 11 | alice springs
# Processing Record 18 of Set 11 | vestmanna
# Processing Record 19 of Set 11 | humboldt
# Processing Record 20 of Set 11 | borba
# Processing Record 21 of Set 11 | coari
# Processing Record 22 of Set 11 | akyab
# Processing Record 23 of Set 11 | la carlota
# Processing Record 24 of Set 11 | haines junction
# Processing Record 25 of Set 11 | kathmandu
# Processing Record 26 of Set 11 | buenos aires
# Processing Record 27 of Set 11 | lompoc
# Processing Record 28 of Set 11 | poum
# Processing Record 29 of Set 11 | tahoua
# Processing Record 30 of Set 11 | dera din panah
# City not found. Skipping...
# Processing Record 31 of Set 11 | port-gentil
# Processing Record 32 of Set 11 | palu
# Processing Record 33 of Set 11 | vanimo
# Processing Record 34 of Set 11 | zory
# Processing Record 35 of Set 11 | bereda
# Processing Record 36 of Set 11 | ouargaye
# Processing Record 37 of Set 11 | manggar
# Processing Record 38 of Set 11 | rottingdean
# Processing Record 39 of Set 11 | brae
# Processing Record 40 of Set 11 | islamkot
# Processing Record 41 of Set 11 | yulara
# Processing Record 42 of Set 11 | vryburg
# Processing Record 43 of Set 11 | sorong
# Processing Record 44 of Set 11 | wellington
# Processing Record 45 of Set 11 | dolbeau
# City not found. Skipping...
# Processing Record 46 of Set 11 | dzhusaly
# City not found. Skipping...
# Processing Record 47 of Set 11 | grafton
# Processing Record 48 of Set 11 | xuddur
# Processing Record 49 of Set 11 | nishihara
# Processing Record 50 of Set 11 | miri
# Processing Record 1 of Set 12 | sandpoint
# Processing Record 2 of Set 12 | kimbe
# Processing Record 3 of Set 12 | todos santos
# Processing Record 4 of Set 12 | diffa
# Processing Record 5 of Set 12 | boende
# Processing Record 6 of Set 12 | pacific grove
# Processing Record 7 of Set 12 | manuk mangkaw
# Processing Record 8 of Set 12 | bamako
# Processing Record 9 of Set 12 | itacoatiara
# Processing Record 10 of Set 12 | blythe
# Processing Record 11 of Set 12 | ketchikan
# Processing Record 12 of Set 12 | chernyshevskiy
# Processing Record 13 of Set 12 | kalianget
# Processing Record 14 of Set 12 | belyy yar
# Processing Record 15 of Set 12 | chokwe
# Processing Record 16 of Set 12 | chirongui
# Processing Record 17 of Set 12 | asfi
# Processing Record 18 of Set 12 | beni suef
# Processing Record 19 of Set 12 | yeniseysk
# Processing Record 20 of Set 12 | vila
# Processing Record 21 of Set 12 | gashua
# Processing Record 22 of Set 12 | antofagasta
# Processing Record 23 of Set 12 | havoysund
# Processing Record 24 of Set 12 | terney
# Processing Record 25 of Set 12 | teguise
# Processing Record 26 of Set 12 | qaqortoq
# Processing Record 27 of Set 12 | acajutla
# Processing Record 28 of Set 12 | asau
# Processing Record 29 of Set 12 | louisbourg
# City not found. Skipping...
# Processing Record 30 of Set 12 | ambon
# Processing Record 31 of Set 12 | provideniya
# Processing Record 32 of Set 12 | pirai do sul
# Processing Record 33 of Set 12 | ugoofaaru
# Processing Record 34 of Set 12 | motygino
# Processing Record 35 of Set 12 | mount isa
# Processing Record 36 of Set 12 | tambopata
# Processing Record 37 of Set 12 | palora
# Processing Record 38 of Set 12 | abu kamal
# Processing Record 39 of Set 12 | sept-iles
# Processing Record 40 of Set 12 | high rock
# Processing Record 41 of Set 12 | alakurtti
# Processing Record 42 of Set 12 | sandwick
# Processing Record 43 of Set 12 | pontes e lacerda
# Processing Record 44 of Set 12 | kholtoson
# Processing Record 45 of Set 12 | marquetalia
# Processing Record 46 of Set 12 | visby
# Processing Record 47 of Set 12 | itanhaem
# Processing Record 48 of Set 12 | karaton
# Processing Record 49 of Set 12 | rosarito
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0         Ushuaia      AR -54.80  -68.30     37.40        69          20
# 1      Georgetown      MY   5.41  100.34     80.60        88          40
# 2   Palmas Bellas      PA   9.23  -80.09     86.00        70          69
# 3         Ahipara      NZ -35.17  173.17     50.52        79          65
# 4    Constitucion      CL -35.33  -72.42     53.76        64          83
# 5   Mount Gambier      AU -37.83  140.77     42.80        93          90
# 6         Ojinaga      MX  29.57 -104.42    104.00        17           1
# 7         Iqaluit      CA  63.75  -68.51     46.40        81          20
# 8  Port Elizabeth      ZA -33.92   25.57     60.80        77          33
# 9    Kruisfontein      ZA -34.00   24.73     55.40        85          64
#
#    Wind Speed Current Description  Rain (inches)  Snow (inches)
# 0        3.36          few clouds           0.00            0.0
# 1        4.70    scattered clouds           0.00            0.0
# 2       11.99          light rain           0.52            0.0
# 3        2.01       broken clouds           0.00            0.0
# 4        4.94       broken clouds           0.00            0.0
# 5        9.17     overcast clouds           0.00            0.0
# 6        4.70           clear sky           0.00            0.0
# 7       12.75          few clouds           0.00            0.0
# 8       16.11    scattered clouds           0.00            0.0
# 9        8.66       broken clouds           0.00            0.0

# %%
# Create the output file (CSV).
output_data_file = "weather_data/WeatherPy_databse.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
